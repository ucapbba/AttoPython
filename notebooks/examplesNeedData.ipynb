# %% [markdown]
# # AttoPython Examples

# %%
import os
import sys

# Ensure the working directory is the repository root so that the relative
# data paths used throughout AttoPython (e.g. "/Data/...") resolve correctly,
# and so "Source"/"MLexamples" can be imported as top-level packages.
if os.path.basename(os.getcwd()) == "notebooks":
    os.chdir(os.path.dirname(os.getcwd()))

REPO_ROOT = os.getcwd()
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

print("Working directory:", os.getcwd())
# Out:
# Working directory: /home/vscode/AttoPython

# %% [markdown]
# ## 5. MNIST digit classification
#
# From `MLexamples/Classification/MNIST/RunSGDClassifier.py`. Trains an `SGDClassifier` on MNIST digit images.
#
# **Requires data:** the cell below (from `SaveMNISTdata.py`) downloads `mnist_784` from OpenML and caches it as `mnist_784.pkl` the first time it's run — this needs internet access and can take a while. If the pickle already exists it's reused.

# %%
import os
from sklearn.datasets import fetch_openml
from MLexamples.Classification.MNIST.DataFunctions import SaveBunchPickle

mnistPickleDir = "/MLexamples/Classification/MNIST/"
mnistPicklePath = os.getcwd() + mnistPickleDir + "mnist_784.pkl"

if os.path.exists(mnistPicklePath):
    print("Found existing", mnistPicklePath, "- skipping download")
else:
    print("Downloading mnist_784 from OpenML (first run only)...")
    mnist = fetch_openml("mnist_784", version=1, as_frame=True)
    SaveBunchPickle("mnist_784.pkl", mnistPickleDir, mnist)
    print("Saved", mnistPicklePath)
# Out:
# ...
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/datasets/_openml.py:109: UserWarning: A network error occurred while downloading https://api.openml.org/api/v1/json/data/list/data_name/mnist_784/limit/2/data_version/1. Retrying...
#   warn(
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /usr/local/lib/python3.10/http/client.py:1303, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1302 """Send a complete request to the server."""
# ...

# %%
from MLexamples.Classification.MNIST.DataFunctions import LoadBunchPickle, PrintDataDetails
from MLexamples.Classification.MNIST.MLFunctions import MLFunctions

mnistData = LoadBunchPickle("mnist_784.pkl", "/MLexamples/Classification/MNIST/")
data = mnistData["data"]
numbers = mnistData["target"]

PrintDataDetails(data)
PrintDataDetails(numbers)

truncate = 10000
images = data.values[:truncate]
numbers = numbers[:truncate]

ML = MLFunctions(images, numbers, 0.01)
ML.MakePredictions(images, numbers)

for prediction, y in zip(ML.predictions, ML.y_test):
    print("prediction = " + str(prediction) + " ### actual = " + str(y))

print("Getting performance measures")
ML.GetPerformanceMeasures()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 from MLexamples.Classification.MNIST.DataFunctions import LoadBunchPickle, PrintDataDetails
#       2 from MLexamples.Classification.MNIST.MLFunctions import MLFunctions
# ----> 4 mnistData = LoadBunchPickle("mnist_784.pkl", "/MLexamples/Classification/MNIST/")
#       5 data = mnistData["data"]
#       6 numbers = mnistData["target"]
#
# File ~/AttoPython/MLexamples/Classification/MNIST/DataFunctions.py:34, in LoadBunchPickle(filename, filepath)
#      32 def LoadBunchPickle(filename: string, filepath: string) -> Bunch:
#      33     cwd = os.getcwd()
# ---> 34     with open(cwd + filepath + filename, 'rb') as bunch:
#      35         data = pickle.load(bunch)
#      36     return data
#
# ...

# %% [markdown]
# ## 6. ARC asymmetry calculation
#
# From `Source/MachineLearning/ARC/Calc_Assym.py`. Calculates asymmetry values across a batch of ARC job output files using `AsymCalculator`.
#
# **Requires data:** job output files under `Data/job/` — not included in this repository, so this cell will raise `FileNotFoundError` until you point it at real job output.

# %%
from Source.MachineLearning.ARC.AsymCalculator import AsymCalculator
from Source.MachineLearning.ARC.AsymCalculatorIO import AsymCalculatorIO

xRange, yRange = 500, 500
_min, _max = 1e-6, 1e2
path = "/Data/"
jobNum = 140603.10
minTask, maxTask = 1, 50

calc = AsymCalculator(path, jobNum, minTask, maxTask, xRange, yRange, _min, _max)
calc.CreateContourHelpers()
calc.CalculateAsymmetries()

print("Calculation finished, output calculations")
io = AsymCalculatorIO(calc)
del calc
print("writing to file......")
io.printToScreen()
io.printToFile()
print("Done")
# Out:
# path /home/vscode/AttoPython/Data/140603.1.1/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.2/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.3/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.4/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.5/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.6/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.7/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.8/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.9/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.10/Data/ does not exisit - moving on....
# path /home/vscode/AttoPython/Data/140603.1.11/Data/ does not exisit - moving on....
# ...

# %% [markdown]
# ## 7. Contour plotting
#
# From `Source/Plotters/ContourPlot/Plot_Contour.py`. Loads and plots a 2D amplitude grid using `ContourDataHelper` + `BasePlotter`.
#
# **Requires data:** the original script pointed outside the repository (`/../../CQSFA/`) at a personal data file. Update `path`/`filename` below to point at your own amplitude grid `.dat` file.

# %%
from Source.Plotters.ContourPlot.ContourDataHelper import ContourDataHelper
from Source.Base.BasePlotter import BasePlotter

xRange, yRange = 750, 750
_min, _max = 1e-4, 1e-1
path = "/Data/140603.10/Data/"
filename = "Amplitude_Grid_w2_1_1000_phi_0.025_750X750.dat"

dataHelper = ContourDataHelper(path, filename, xRange, yRange, _min, _max)
dataHelper.LoadToArray()
dataHelper.CreateArray(7)
dataHelper.Normalise()

plotter = BasePlotter(dataHelper)
plotter.PlotColourMesh()
